# %%
import pandas as pd

# %%
df = pd.read_csv("../data/cleaned_featured_jobs.csv")

# %%
df.head()

# %%
print(df.columns.tolist())

# %%
skills = [
    "Python",
    "SQL",
    "Excel",
    "Power BI",
    "Tableau",
    "Machine Learning",
    "Statistics",
    "Pandas",
    "NumPy",
    "R"
]

# %%
import re

skill_counts = {}

for skill in skills:

    if skill == "R":
        count = df["job_description"].str.contains(
            r"\bR\b",
            case=False,
            na=False,
            regex=True
        ).sum()

    else:
        count = df["job_description"].str.contains(
            re.escape(skill),
            case=False,
            na=False
        ).sum()

    skill_counts[skill] = count

print(skill_counts)

# %%
skills_df = pd.DataFrame(
    list(skill_counts.items()),
    columns=["Skill", "Count"]
)

skills_df = skills_df.sort_values(
    by="Count",
    ascending=False
)

skills_df

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(skills_df["Skill"], skills_df["Count"])

plt.title("Top Skills in Data Analyst Job Descriptions")
plt.xlabel("Skills")
plt.ylabel("Frequency")
plt.xticks(rotation=45)

plt.tight_layout()

plt.savefig("../screenshots/skills_extraction.png")
plt.show()

# %%
skills_df.to_csv(
    "../data/extracted_skills.csv",
    index=False
)
